# %% [markdown]
# # Craigslist Vehicle Listing Dataset
#
# ### Exploratory Data Analysis & the ETL Process
#
# ---

# %% [markdown]
# ### Objective
#
# The goal of this project is to practice my SQL and Python skills using a real-world dataset.
#
# <b>The steps will be as follows:</b>
#
# EXTRACT data from a database of Craigslist vehicle postings found on Kaggle into a Pandas DataFrame.
#
# (Source: https://www.kaggle.com/austinreese/craigslist-carstrucks-data)
#
# Clean and TRANSFORM the data into a smaller, more useful and manageable set in order to extract insights and visualize trends.
#
# Use SQLite3 to create a database with multiple tables.
#
# Also, save the cleaned dataset as a .csv file for use in future projects.
#
# ---

# %% [markdown]
# ### Description of Data
#
#  This data set consists of all vehicles listed to Craigslist in the US. It contains most all relevant information that Craigslist provides on car sales including columns like price, condition, manufacturer, latitude/longitude, and 18 other categories.
#
#  ---

# %% [markdown]
# <b> Import Dependencies </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Extract & Explore Data

# %%
# Read the data from csv and put it in a dataframe

raw_df = pd.read_csv("../Resources/vehicles.csv")

raw_df.head()
# Out:
#            id                                                url  \
# 0  7184791621  https://duluth.craigslist.org/ctd/d/duluth-200...
# 1  7184773187  https://duluth.craigslist.org/cto/d/saginaw-20...
# 2  7193375964  https://newhaven.craigslist.org/cto/d/stratfor...
# 3  7195108810  https://albuquerque.craigslist.org/cto/d/albuq...
# 4  7184712241  https://duluth.craigslist.org/ctd/d/rush-city-...
#
#               region                          region_url  price    year  \
# 0  duluth / superior       https://duluth.craigslist.org   6995  2000.0
# 1  duluth / superior       https://duluth.craigslist.org   8750  2013.0
# 2          new haven     https://newhaven.craigslist.org  10900  2013.0
# 3        albuquerque  https://albuquerque.craigslist.org  12500  2003.0
# 4  duluth / superior       https://duluth.craigslist.org  16995  2007.0
#
#   manufacturer                  model  condition    cylinders  ... drive  \
# 0          gmc        new sierra 1500  excellent  8 cylinders  ...   4wd
# 1      hyundai                 sonata  excellent  4 cylinders  ...   fwd
# 2       toyota                  prius       good  4 cylinders  ...   fwd
# 3   mitsubishi                 lancer       good  4 cylinders  ...   4wd
# 4          gmc  sierra classic 2500hd       good  8 cylinders  ...   4wd
#
#         size   type paint_color  \
# 0        NaN    NaN         red
# 1        NaN    NaN        grey
# 2        NaN    NaN        blue
# 3   mid-size  sedan        grey
# 4  full-size  truck       white
#
#                                            image_url  \
# 0  https://images.craigslist.org/00n0n_f06ykBMcdh...
# 1  https://images.craigslist.org/00d0d_kgZ6xoeRw2...
# 2  https://images.craigslist.org/00d0d_3sHGxPbY2O...
# 3  https://images.craigslist.org/00m0m_4a8Pb6JbMG...
# 4  https://images.craigslist.org/01414_g093aPtSMW...
#
#                                          description county state      lat  \
# 0  2000 *** GMC New Sierra 1500 Ext Cab 157.5  WB...    NaN    mn  46.8433
# 1  For Sale:  2013 Hyundai Sonata GLS - $8750.  O...    NaN    mn  46.9074
# 2  2013 Prius V Model Two. One owner—must sell my...    NaN    ct  41.1770
# 3  2003 Mitsubishi Lancer Evolution, silver.  Abo...    NaN    nm  35.1868
# 4  **Bad Credit, No Credit... No Problem!**2007 G...    NaN    mn  45.6836
#
#        long
# 0  -92.2550
# 1  -92.4638
# 2  -73.1336
# 3 -106.6650
# 4  -92.9648
#
# [5 rows x 25 columns]

# %%
# explore column names

raw_df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
# Explore data set dimensions

raw_df.shape

# There are 423,857 listings, with 21 columns.
# Out:
# (423857, 25)

# %% [markdown]
# <b>The data set has 25 columns, but we will not need all  of them for this analysis.</b>
#
# Since my goal is to practice SQL, I will turn this single dataset into a relational database, using the ID column as the primary key.
#
# - Listings table: includes all the listing information that does not have to do with the location.
# - Location table: includes region, county, state, latitude, and longitude columns.
# - Description table: includes the descriptions for each listing
#
# In order to mimic a project in which there are multiple data sources, I will separate the dataset into three different tables.
# I will perform the transformation process on just the main Listings table, and will not touch the other two tables.
# Once I have completed the bulk of the data transformation, I will join the data tables.
#
# <b>Upon initial exploration, I do not see a use-case for the URL or VIN columns, so they will be dropped.</b>

# %%
raw_df.drop(['url','region_url','vin','image_url'], axis=1, inplace=True)
raw_df.head()
# Out:
#            id             region  price    year manufacturer  \
# 0  7184791621  duluth / superior   6995  2000.0          gmc
# 1  7184773187  duluth / superior   8750  2013.0      hyundai
# 2  7193375964          new haven  10900  2013.0       toyota
# 3  7195108810        albuquerque  12500  2003.0   mitsubishi
# 4  7184712241  duluth / superior  16995  2007.0          gmc
#
#                    model  condition    cylinders    fuel  odometer  ...  \
# 0        new sierra 1500  excellent  8 cylinders     gas  167783.0  ...
# 1                 sonata  excellent  4 cylinders     gas   90821.0  ...
# 2                  prius       good  4 cylinders  hybrid   92800.0  ...
# 3                 lancer       good  4 cylinders     gas       NaN  ...
# 4  sierra classic 2500hd       good  8 cylinders  diesel  254217.0  ...
#
#   transmission drive       size   type paint_color  \
# 0    automatic   4wd        NaN    NaN         red
# 1    automatic   fwd        NaN    NaN        grey
# 2    automatic   fwd        NaN    NaN        blue
# 3       manual   4wd   mid-size  sedan        grey
# 4    automatic   4wd  full-size  truck       white
#
#                                          description county  state      lat  \
# 0  2000 *** GMC New Sierra 1500 Ext Cab 157.5  WB...    NaN     mn  46.8433
# 1  For Sale:  2013 Hyundai Sonata GLS - $8750.  O...    NaN     mn  46.9074
# 2  2013 Prius V Model Two. One owner—must sell my...    NaN     ct  41.1770
# 3  2003 Mitsubishi Lancer Evolution, silver.  Abo...    NaN     nm  35.1868
# 4  **Bad Credit, No Credit... No Problem!**2007 G...    NaN     mn  45.6836
#
#        long
# 0  -92.2550
# 1  -92.4638
# 2  -73.1336
# 3 -106.6650
# 4  -92.9648
#
# [5 rows x 21 columns]

# %%
# Inspect the remaining columns
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423857 entries, 0 to 423856
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            423857 non-null  int64
#  1   region        423857 non-null  object
#  2   price         423857 non-null  int64
#  3   year          328743 non-null  float64
#  4   manufacturer  313242 non-null  object
#  5   model         325384 non-null  object
#  6   condition     176719 non-null  object
#  7   cylinders     197679 non-null  object
#  8   fuel          327214 non-null  object
#  9   odometer      270585 non-null  float64
#  10  title_status  327759 non-null  object
#  11  transmission  328065 non-null  object
#  12  drive         231119 non-null  object
#  13  size          102627 non-null  object
#  14  type          241157 non-null  object
#  15  paint_color   222203 non-null  object
#  16  description   329654 non-null  object
#  17  county        0 non-null       float64
#  18  state         423857 non-null  object
#  19  lat           324404 non-null  float64
#  20  long          324404 non-null  float64
# dtypes: float64(5), int64(2), object(14)
# memory usage: 67.9+ MB

# %%
# Set index for the main dataframe

raw_df.set_index('id')
# Out:
#                        region  price    year manufacturer  \
# id
# 7184791621  duluth / superior   6995  2000.0          gmc
# 7184773187  duluth / superior   8750  2013.0      hyundai
# 7193375964          new haven  10900  2013.0       toyota
# 7195108810        albuquerque  12500  2003.0   mitsubishi
# 7184712241  duluth / superior  16995  2007.0          gmc
# ...                       ...    ...     ...          ...
# 7184919761  duluth / superior   1600  2006.0      hyundai
# 7184844576  duluth / superior   9000  2003.0       toyota
# 7184805809  duluth / superior    700  1994.0         ford
# 7184791927  duluth / superior   3800  1999.0      lincoln
# 7195109037        albuquerque   8650  2015.0       nissan
#
#                             model  condition    cylinders    fuel  odometer  \
# id
# 7184791621        new sierra 1500  excellent  8 cylinders     gas  167783.0
# 7184773187                 sonata  excellent  4 cylinders     gas   90821.0
# 7193375964                  prius       good  4 cylinders  hybrid   92800.0
# 7195108810                 lancer       good  4 cylinders     gas       NaN
# 7184712241  sierra classic 2500hd       good  8 cylinders  diesel  254217.0
# ...                           ...        ...          ...     ...       ...
# 7184919761                 sonata       fair  6 cylinders     gas  159980.0
# 7184844576        sequoia limited  excellent  8 cylinders     gas  160000.0
# 7184805809                  f-150       fair  6 cylinders     gas  212000.0
# 7184791927               town car  excellent  8 cylinders     gas  160000.0
# 7195109037                  versa        NaN          NaN     gas  160526.0
#
#            title_status transmission drive       size   type paint_color  \
# id
# 7184791621        clean    automatic   4wd        NaN    NaN         red
# 7184773187        clean    automatic   fwd        NaN    NaN        grey
# 7193375964        clean    automatic   fwd        NaN    NaN        blue
# 7195108810        clean       manual   4wd   mid-size  sedan        grey
# 7184712241        clean    automatic   4wd  full-size  truck       white
# ...                 ...          ...   ...        ...    ...         ...
# 7184919761        clean    automatic   fwd        NaN  sedan        blue
# 7184844576        clean    automatic   4wd  full-size    SUV       green
# 7184805809        clean       manual   rwd        NaN    NaN       green
# 7184791927        clean    automatic   rwd        NaN  sedan         NaN
# 7195109037        clean    automatic   fwd    compact  sedan      silver
#
#                                                   description  county state  \
# id
# 7184791621  2000 *** GMC New Sierra 1500 Ext Cab 157.5  WB...     NaN    mn
# 7184773187  For Sale:  2013 Hyundai Sonata GLS - $8750.  O...     NaN    mn
# 7193375964  2013 Prius V Model Two. One owner—must sell my...     NaN    ct
# 7195108810  2003 Mitsubishi Lancer Evolution, silver.  Abo...     NaN    nm
# 7184712241  **Bad Credit, No Credit... No Problem!**2007 G...     NaN    mn
# ...                                                       ...     ...   ...
# 7184919761  Motor runs and drives good. Transmission shift...     NaN    mn
# 7184844576  2 owner 0 rust not from here... Leather ,roof ...     NaN    mn
# 7184805809  I'm selling this beautiful old pickup that I j...     NaN    mn
# 7184791927  1999 *** Lincoln Town Car 4dr Sdn Signature Se...     NaN    mn
# 7195109037  2015 Nissan Versa S     Offered by: Southwest ...     NaN    nm
#
#                 lat      long
# id
# 7184791621  46.8433  -92.2550
# 7184773187  46.9074  -92.4638
# 7193375964  41.1770  -73.1336
# 7195108810  35.1868 -106.6650
# 7184712241  45.6836  -92.9648
# ...             ...       ...
# 7184919761  46.8348  -92.0742
# 7184844576  46.9369  -91.9325
# 7184805809  46.7715  -92.1279
# 7184791927  46.8433  -92.2550
# 7195109037  35.1851 -106.5850
#
# [423857 rows x 20 columns]

# %%
# Create Listings_df

listings_df = raw_df[['id','price','year','manufacturer','model','condition','cylinders','fuel','odometer','title_status','transmission','drive','size','type','paint_color']].copy()
listings_df.head()
# Out:
#            id  price    year manufacturer                  model  condition  \
# 0  7184791621   6995  2000.0          gmc        new sierra 1500  excellent
# 1  7184773187   8750  2013.0      hyundai                 sonata  excellent
# 2  7193375964  10900  2013.0       toyota                  prius       good
# 3  7195108810  12500  2003.0   mitsubishi                 lancer       good
# 4  7184712241  16995  2007.0          gmc  sierra classic 2500hd       good
#
#      cylinders    fuel  odometer title_status transmission drive       size  \
# 0  8 cylinders     gas  167783.0        clean    automatic   4wd        NaN
# 1  4 cylinders     gas   90821.0        clean    automatic   fwd        NaN
# 2  4 cylinders  hybrid   92800.0        clean    automatic   fwd        NaN
# 3  4 cylinders     gas       NaN        clean       manual   4wd   mid-size
# 4  8 cylinders  diesel  254217.0        clean    automatic   4wd  full-size
#
#     type paint_color
# 0    NaN         red
# 1    NaN        grey
# 2    NaN        blue
# 3  sedan        grey
# 4  truck       white

# %%
# Create location df

location_df=raw_df[['id','region','county','state','lat','long']]
location_df.head()
# Out:
#            id             region  county state      lat      long
# 0  7184791621  duluth / superior     NaN    mn  46.8433  -92.2550
# 1  7184773187  duluth / superior     NaN    mn  46.9074  -92.4638
# 2  7193375964          new haven     NaN    ct  41.1770  -73.1336
# 3  7195108810        albuquerque     NaN    nm  35.1868 -106.6650
# 4  7184712241  duluth / superior     NaN    mn  45.6836  -92.9648

# %%
# Create Description df

desc_df=raw_df[['id','description']]
desc_df.head()
# Out:
#            id                                        description
# 0  7184791621  2000 *** GMC New Sierra 1500 Ext Cab 157.5  WB...
# 1  7184773187  For Sale:  2013 Hyundai Sonata GLS - $8750.  O...
# 2  7193375964  2013 Prius V Model Two. One owner—must sell my...
# 3  7195108810  2003 Mitsubishi Lancer Evolution, silver.  Abo...
# 4  7184712241  **Bad Credit, No Credit... No Problem!**2007 G...

# %% [markdown]
# <b> Now that we have our three separated dataframes, we can being to TRANSFORM the Listings DataFrame. </b>
#
# First, we will check for columns that have greater than 40% null values and remove them.
# Then, we can drop rows with null values.
#
# We will keep track of the number of rows along the way.

# %%
# Determine number of rows in listings_df

listings_df.shape

# We see that we are starting out with 423,857 vehicle listings.
# Out:
# (423857, 15)

# %%
# Determine number of nulls for each row

listings_df.isna().sum()
# Out:
# id                   0
# price                0
# year             95114
# manufacturer    110615
# model            98473
# condition       247138
# cylinders       226178
# fuel             96643
# odometer        153272
# title_status     96098
# transmission     95792
# drive           192738
# size            321230
# type            182700
# paint_color     201654
# dtype: int64

# %%
# Create a function that drops columns with >40% null values

null_cols = listings_df.isna().sum()

def null_check(na, threshold = 0.4):
    null_check_pass = []
    
    for i in na.keys():
        if (na[i])/listings_df.shape[0]<threshold:
            null_check_pass.append(i)
    return null_check_pass

# Create a new DataFrame that houses the columns with <40% null values

clean_listings_df = listings_df[null_check(null_cols)]

# %%
# Let's see how many columns are left

clean_listings_df.shape

# There are 423,857 listings remaining
# Out:
# (423857, 9)

# %%
# We see that the number of columns was cut down from 16 to 9. Let's find out which columns remain

clean_listings_df.columns

# We can see that condition, cylinders, drive, size, type, and paint color were dropped
# Out:
# Index(['id', 'price', 'year', 'manufacturer', 'model', 'fuel', 'odometer',
#        'title_status', 'transmission'],
#       dtype='object')

# %%
# Now we need to drop rows with missing values.

clean_listings_df = clean_listings_df.dropna()

clean_listings_df.shape

# We now have 253,944 rows of data left, down from 423,857 (-63%)
# Out:
# (253944, 9)

# %% [markdown]
# <b> Inspect the remaining columns to see what data we have</b>

# %%
### Make sure there are no nulls

clean_listings_df.isna().sum()

# We have successfully removed null values, and are still left with over 250,000 listings.
# Out:
# id              0
# price           0
# year            0
# manufacturer    0
# model           0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# dtype: int64

# %%
# Find unique values in each column and look for issues

# Categorical Columns
print('Categorical Columns: \n\n')
print(f'Unique Years: ',clean_listings_df.year.unique(),'\n')
print(f'Unique Manufacturers: ',clean_listings_df.manufacturer.unique(),'\n')
print(f'Unique Models: ',clean_listings_df.model.unique(),'\n')
print(f'Unique Fuel Types: ',clean_listings_df.fuel.unique(),'\n')
print(f'Unique Title Statuses: ',clean_listings_df.title_status.unique(),'\n')
print(f'Unique Transmission Types: ',clean_listings_df.transmission.unique(),'\n\n')

# Numberical Columns
print('Numerical Columns: \n\n')
clean_listings_df.describe()
# Out:
# Categorical Columns:
#
#
# Unique Years:  [2000. 2013. 2007. 2012. 2010. 2011. 2014. 2004. 2009. 2008. 1994. 1997.
#  2019. 2015. 2003. 2016. 2006. 2017. 2005. 1964. 1998. 2001. 2002. 2018.
#  1989. 1990. 1967. 1992. 1993. 1999. 1986. 1995. 1996. 2020. 1963. 1966.
#  1983. 1972. 1952. 1987. 1981. 1991. 1979. 1960. 1927. 1973. 1977. 1959.
#  1969. 1982. 1953. 1978. 1988. 1957. 1968. 1984. 1933. 1934. 1980. 1985.
#  1970. 1974. 1971. 1962. 2021. 1965. 1941. 1919. 1939. 1948. 1940. 1932.
#  1975. 1950. 1976. 1958. 1930. 1955. 1956. 1951. 1949. 1929. 1954. 1923.
#  1931. 1961. 1936. 1921. 1947. 1946. 1937. 1935. 1926. 1928. 1924. 1938.
#  1911. 1942.]
#
# Unique Manufacturers:  ['gmc' 'hyundai' 'toyota' 'ford' 'chevrolet' 'ram' 'buick' 'jeep' 'dodge'
#  'subaru' 'nissan' 'audi' 'rover' 'lexus' 'honda' 'mini' 'mercedes-benz'
#  'cadillac' 'bmw' 'kia' 'volvo' 'jaguar' 'chrysler' 'acura' 'mitsubishi'
#  'mazda' 'volkswagen' 'pontiac' 'lincoln' 'infiniti' 'saturn' 'mercury'
#  'ferrari' 'fiat' 'tesla' 'land rover' 'harley-davidson' 'datsun'
#  'alfa-romeo' 'morgan' 'aston-martin' 'porche']
#
# Unique Models:  ['new sierra 1500' 'sonata' 'prius' ... '280 sl' 'sienns xlt awd'
#  'ranchero gt cobra']
#
# Unique Fuel Types:  ['gas' 'hybrid' 'diesel' 'electric' 'other']
#
# Unique Title Statuses:  ['clean' 'lien' 'rebuilt' 'salvage' 'parts only' 'missing']
#
# Unique Transmission Types:  ['automatic' 'manual' 'other']
#
#
# Numerical Columns:
#                  id         price           year      odometer
# count  2.539440e+05  2.539440e+05  253944.000000  2.539440e+05
# mean   7.189045e+09  2.646382e+04    2011.257793  9.879409e+04
# std    4.749839e+06  5.014776e+06       7.537648  1.096470e+05
# min    7.178302e+09  0.000000e+00    1911.000000  0.000000e+00
# 25%    7.185454e+09  5.490000e+03    2008.000000  4.500000e+04
# 50%    7.190017e+09  1.100000e+04    2013.000000  9.201150e+04
# 75%    7.193333e+09  1.995000e+04    2016.000000  1.372510e+05
# max    7.195225e+09  2.490531e+09    2021.000000  1.000000e+07

# %% [markdown]
# <b> Upon inspection, we see a few things that need to be addressed:</b>
#
#     - The minimum price is $0, which can not be true
#
#     - The maximum price is over $2 Billion, which needs to be checked
#
#     - Some things are misspelled or mislabeled, like "Porche" instead of "Porsche"
#
#     - There is a manufacturer entry for "Harley Davidson", which is a motorcycle brand
#
#     - The "minimum" of the year column is 1911. While it's possible this is a real listing, we should limit the dataset by removing outliers
#
#
#
#
# <b> Let's start by plotting some charts to try and visualize outliers. </b>
#
# <b> We can begin with price </b>

# %%
# Box plot on prices to see the normal range (not including outliers):

fig = plt.figure(figsize=(5,5))
plt.title("Craigslist Vehicle List Prices")
plt.ylabel("Price ($)")
plt.boxplot('price', data=clean_listings_df,showfliers=False)

# We see that values over $40,000 are considered outliers. 
# Considering that most cars on Craigslist are used, this number seems reasonable. 
# However, there are many cars that are worth over $40k used.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbdf8a5be80>,
#   <matplotlib.lines.Line2D at 0x7fbdf8a72220>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbdf8a72580>,
#   <matplotlib.lines.Line2D at 0x7fbdf8a728e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbdf8a5bb20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbdf8a72c40>],
#  'fliers': [],
#  'means': []}

# %%
# Remove cars with $0 price

clean_listings_df = clean_listings_df[clean_listings_df['price']>0]

clean_listings_df.shape

# We have cut down the number of listings from 253,944 to 233,566 (-8%)
# Out:
# (233566, 9)

# %%
fig = plt.figure(figsize=(5,5))
plt.hist(clean_listings_df['price'],50)
# Out:
# (array([2.33563e+05, 0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([1.00000000e+00, 4.98106285e+07, 9.96212560e+07, 1.49431883e+08,
#         1.99242511e+08, 2.49053138e+08, 2.98863766e+08, 3.48674393e+08,
#         3.98485021e+08, 4.48295648e+08, 4.98106276e+08, 5.47916903e+08,
#         5.97727531e+08, 6.47538158e+08, 6.97348786e+08, 7.47159413e+08,
#         7.96970041e+08, 8.46780668e+08, 8.96591296e+08, 9.46401923e+08,
#         9.96212551e+08, 1.04602318e+09, 1.09583381e+09, 1.14564443e+09,
#         1.19545506e+09, 1.24526569e+09, 1.29507632e+09, 1.34488694e+09,
#         1.39469757e+09, 1.44450820e+09, 1.49431883e+09, 1.54412945e+09,
#         1.59394008e+09, 1.64375071e+09, 1.69356134e+09, 1.74337196e+09,
#         1.79318259e+09, 1.84299322e+09, 1.89280385e+09, 1.94261447e+09,
#         1.99242510e+09, 2.04223573e+09, 2.09204636e+09, 2.14185698e+09,
#         2.19166761e+09, 2.24147824e+09, 2.29128887e+09, 2.34109949e+09,
#         2.39091012e+09, 2.44072075e+09, 2.49053138e+09]),
#  <BarContainer object of 50 artists>)

# %%
# Since our  Let's take a look at the listings greater than $100,000 and see if we can exclude them

clean_listings_df[clean_listings_df['price']>100000]

# There are 203 listings above $100,000. This is an insignificant amount in relation to the size of our full data set, so we can safely exclude it.

# Downsides of excluding it are that we are losing listings for some high-dollar cars, such as Audi R8s and Ferraris.

# Based on this list, only a few of the cars should be at their listed prices. 
# In some cases, it appears there was an extra '0' added to the number, or two 0's if they are missing a decimal place.
# In others, it looks like a phone number was used in the list price section.
# There are also a few that look like they used an arbitrary number.
# Based on this list, we can ignore the listings above
# Out:
#                 id    price    year manufacturer              model fuel  \
# 807     7187052743   106899  2004.0      ferrari  360 modena spyder  gas
# 2735    7192116434  1495000  2014.0        lexus             is 250  gas
# 3778    7190627325   239999  1933.0         ford           victoria  gas
# 5986    7194931599   137500  2017.0         audi          r8 spyder  gas
# 6099    7194507428   112900  2020.0    chevrolet           corvette  gas
# ...            ...      ...     ...          ...                ...  ...
# 399412  7187548159   119995  2020.0    chevrolet  corvette stingray  gas
# 402534  7184297439   124975  2015.0         audi             r8 v10  gas
# 409983  7193568300   104888  2020.0    chevrolet           corvette  gas
# 410000  7193567798   107888  2020.0    chevrolet           corvette  gas
# 423612  7185047348   101999  2020.0    chevrolet   silverado 3500hd  gas
#
#         odometer title_status transmission
# 807      34123.0        clean    automatic
# 2735     79577.0        clean    automatic
# 3778         5.0        clean    automatic
# 5986     22752.0        clean    automatic
# 6099       718.0        clean    automatic
# ...          ...          ...          ...
# 399412     932.0        clean    automatic
# 402534   16000.0        clean    automatic
# 409983    2011.0        clean    automatic
# 410000      84.0        clean    automatic
# 423612    7200.0        clean    automatic
#
# [203 rows x 9 columns]

# %%
# Let's remove listings above $100,000.

clean_listings_df=clean_listings_df[clean_listings_df['price']<100000]
clean_listings_df.shape

# We have cut down the data set to 233,361 listings (-0.1%)
# Out:
# (233361, 9)

# %%
# Let's look at the histogram distribution again

fig = plt.figure(figsize=(5,5))
plt.hist(clean_listings_df['price'],100)
# Out:
# (array([6.3330e+03, 4.8540e+03, 7.9080e+03, 1.0696e+04, 1.1560e+04,
#         1.2053e+04, 1.2157e+04, 1.1827e+04, 1.0883e+04, 1.0467e+04,
#         8.1130e+03, 8.0760e+03, 8.3900e+03, 8.1850e+03, 8.4060e+03,
#         7.5580e+03, 7.3270e+03, 6.5570e+03, 6.0190e+03, 6.4000e+03,
#         3.5300e+03, 4.1660e+03, 3.8650e+03, 3.3400e+03, 3.6320e+03,
#         2.4690e+03, 2.7530e+03, 2.7030e+03, 2.4080e+03, 3.1990e+03,
#         1.3350e+03, 1.8030e+03, 1.7700e+03, 1.8660e+03, 2.2150e+03,
#         1.3340e+03, 1.6470e+03, 1.3440e+03, 1.2360e+03, 1.9920e+03,
#         5.0900e+02, 9.1400e+02, 9.4600e+02, 7.7800e+02, 9.0000e+02,
#         5.1400e+02, 5.6400e+02, 4.8700e+02, 4.2400e+02, 7.8200e+02,
#         1.3700e+02, 2.5700e+02, 3.2300e+02, 1.6900e+02, 2.4600e+02,
#         1.9500e+02, 2.0300e+02, 2.0200e+02, 2.1100e+02, 3.6300e+02,
#         6.0000e+01, 9.8000e+01, 1.8100e+02, 7.9000e+01, 1.4500e+02,
#         1.4900e+02, 1.1000e+02, 1.1200e+02, 9.6000e+01, 1.7000e+02,
#         2.8000e+01, 2.6000e+01, 7.9000e+01, 3.9000e+01, 4.3000e+01,
#         3.5000e+01, 3.2000e+01, 3.2000e+01, 3.4000e+01, 1.0400e+02,
#         6.0000e+00, 2.0000e+01, 1.4000e+01, 5.0000e+00, 1.6000e+01,
#         1.0000e+01, 0.0000e+00, 3.0000e+01, 5.0000e+00, 4.0000e+01,
#         9.0000e+00, 1.0000e+00, 4.0000e+00, 0.0000e+00, 7.0000e+00,
#         5.0000e+00, 1.0000e+01, 4.0000e+00, 5.0000e+00, 1.8000e+01]),
#  array([1.000000e+00, 1.000980e+03, 2.000960e+03, 3.000940e+03,
#         4.000920e+03, 5.000900e+03, 6.000880e+03, 7.000860e+03,
#         8.000840e+03, 9.000820e+03, 1.000080e+04, 1.100078e+04,
#         1.200076e+04, 1.300074e+04, 1.400072e+04, 1.500070e+04,
#         1.600068e+04, 1.700066e+04, 1.800064e+04, 1.900062e+04,
#         2.000060e+04, 2.100058e+04, 2.200056e+04, 2.300054e+04,
#         2.400052e+04, 2.500050e+04, 2.600048e+04, 2.700046e+04,
#         2.800044e+04, 2.900042e+04, 3.000040e+04, 3.100038e+04,
#         3.200036e+04, 3.300034e+04, 3.400032e+04, 3.500030e+04,
#         3.600028e+04, 3.700026e+04, 3.800024e+04, 3.900022e+04,
#         4.000020e+04, 4.100018e+04, 4.200016e+04, 4.300014e+04,
#         4.400012e+04, 4.500010e+04, 4.600008e+04, 4.700006e+04,
#         4.800004e+04, 4.900002e+04, 5.000000e+04, 5.099998e+04,
#         5.199996e+04, 5.299994e+04, 5.399992e+04, 5.499990e+04,
#         5.599988e+04, 5.699986e+04, 5.799984e+04, 5.899982e+04,
#         5.999980e+04, 6.099978e+04, 6.199976e+04, 6.299974e+04,
#         6.399972e+04, 6.499970e+04, 6.599968e+04, 6.699966e+04,
#         6.799964e+04, 6.899962e+04, 6.999960e+04, 7.099958e+04,
#         7.199956e+04, 7.299954e+04, 7.399952e+04, 7.499950e+04,
#         7.599948e+04, 7.699946e+04, 7.799944e+04, 7.899942e+04,
#         7.999940e+04, 8.099938e+04, 8.199936e+04, 8.299934e+04,
#         8.399932e+04, 8.499930e+04, 8.599928e+04, 8.699926e+04,
#         8.799924e+04, 8.899922e+04, 8.999920e+04, 9.099918e+04,
#         9.199916e+04, 9.299914e+04, 9.399912e+04, 9.499910e+04,
#         9.599908e+04, 9.699906e+04, 9.799904e+04, 9.899902e+04,
#         9.999900e+04]),
#  <BarContainer object of 100 artists>)

# %%
# Looking at listings between $80,000 and $100,000

clean_listings_df[clean_listings_df['price']>80000]

# We see that these 205 listings include some classic cars, high-end sports cars, and some late-model vehicles that retail for well over their asking prices. 
# Since these listings look reasonable, we will keep the upper limit of the dataset at $100,000
# Out:
#                 id  price    year   manufacturer  \
# 1996    7187776823  81999  2019.0           ford
# 2396    7186006224  81999  2019.0           ford
# 2568    7185369022  81999  2019.0           ford
# 2702    7194616684  89995  2020.0           ford
# 3273    7189861089  88999  2010.0        ferrari
# ...            ...    ...     ...            ...
# 410758  7189182921  90000  2000.0           jeep
# 411084  7188326497  89988  1970.0      chevrolet
# 418166  7190820613  87500  1970.0          dodge
# 419376  7190160495  96500  1969.0      chevrolet
# 422187  7194144438  83995  2017.0  mercedes-benz
#
#                                                     model    fuel  odometer  \
# 1996                            f350 powerstroke platinum  diesel   17328.0
# 2396                             f350 diesels powerstroke  diesel   17328.0
# 2568                             f350 diesel power stroke  diesel   17328.0
# 2702    f-350 lifted platinum crew cab power stroke di...   other   12504.0
# 3273                                    california 19,000     gas   19000.0
# ...                                                   ...     ...       ...
# 410758                                        wrangler tj     gas  121000.0
# 411084                                           chevelle     gas      51.0
# 418166                                            coronet     gas   45606.0
# 419376                                             camaro     gas    2829.0
# 422187                                            g-class     gas   45697.0
#
#        title_status transmission
# 1996          clean    automatic
# 2396          clean    automatic
# 2568          clean    automatic
# 2702          clean    automatic
# 3273          clean    automatic
# ...             ...          ...
# 410758         lien       manual
# 411084        clean       manual
# 418166        clean       manual
# 419376        clean       manual
# 422187        clean    automatic
#
# [205 rows x 9 columns]

# %%
# Now that we have pruned the top end of the dataset, let's look at listings with low prices.

clean_listings_df[clean_listings_df['price']<1000]

# There are 5,689 listings under $1,000. Let's understand this small set.
# Out:
#                 id  price    year manufacturer        model fuel  odometer  \
# 53      7183985811    500  1998.0        honda        civic  gas  242613.0
# 146     7191729475    500  2006.0        honda  civic coupe  gas  210000.0
# 147     7191729087    500  1997.0    chevrolet       blazer  gas  158000.0
# 569     7182805939    700  1998.0         ford     windstar  gas  136000.0
# 579     7193371115      1  2010.0          gmc  sierra 1500  gas  186049.0
# ...            ...    ...     ...          ...          ...  ...       ...
# 423299  7185153516    900  1997.0      pontiac   grand prix  gas  168319.0
# 423568  7193446369    500  2001.0         ford       taurus  gas  140000.0
# 423819  7191893229      1  2014.0      hyundai      elantra  gas   45000.0
# 423850  7195116716    750  2002.0       saturn          sc2  gas   40000.0
# 423854  7184805809    700  1994.0         ford        f-150  gas  212000.0
#
#        title_status transmission
# 53            clean    automatic
# 146           clean    automatic
# 147           clean    automatic
# 569           clean    automatic
# 579           clean    automatic
# ...             ...          ...
# 423299        clean    automatic
# 423568        clean        other
# 423819      rebuilt    automatic
# 423850      missing       manual
# 423854        clean       manual
#
# [5689 rows x 9 columns]

# %%
# We can create a dataframe for the cheap listings to simplify the code in the next few cells.

cheap_df = clean_listings_df[clean_listings_df['price']<1000]

#fig = plt.figure(figsize=(5,5))
#plt.hist(cheap_df,10)

cheap_df.describe()
# Out:
#                  id        price         year      odometer
# count  5.689000e+03  5689.000000  5689.000000  5.689000e+03
# mean   7.188994e+09   380.946564  2011.481104  8.974761e+04
# std    4.686374e+06   267.732438     7.989315  9.060866e+04
# min    7.178387e+09     1.000000  1932.000000  0.000000e+00
# 25%    7.185117e+09   175.000000  2007.000000  3.418500e+04
# 50%    7.189934e+09   322.000000  2014.000000  7.021600e+04
# 75%    7.193239e+09   550.000000  2017.000000  1.286950e+05
# max    7.195218e+09   999.000000  2020.000000  2.500000e+06

# %%
# Let's look at the histogram distribution broken out by every $10 within the first $1,000.

fig = plt.figure(figsize=(5,5))
plt.hist(cheap_df['price'],100)
# Out:
# (array([452.,  23.,  12.,  15.,   5.,  13.,  16.,  23.,  62., 348.,  30.,
#          59.,  87.,   9.,  84.,  73.,  52., 123.,  52., 108.,  97.,  98.,
#          55.,  82., 117., 112.,  83., 142., 119., 153.,  61.,  59.,  70.,
#          87.,  61., 104.,  81.,  58.,  60.,  65.,  61.,  79.,  29.,  47.,
#          54.,  20.,  43.,  23.,  20.,  89., 272.,  24.,  24.,  35.,  28.,
#          34.,  45.,  19.,  24.,  49., 110.,  30.,  36.,   7.,   4.,  34.,
#          28.,  22.,   6.,  29., 117.,   2.,   6.,   4.,   7.,  92.,   6.,
#           6.,  19., 100., 157.,   0.,  19.,   0.,   0.,  49.,   1.,   3.,
#           2.,  31., 135.,   0.,   2.,   2.,   0.,  50.,   0.,  10.,   3.,
#         131.]),
#  array([  1.  ,  10.98,  20.96,  30.94,  40.92,  50.9 ,  60.88,  70.86,
#          80.84,  90.82, 100.8 , 110.78, 120.76, 130.74, 140.72, 150.7 ,
#         160.68, 170.66, 180.64, 190.62, 200.6 , 210.58, 220.56, 230.54,
#         240.52, 250.5 , 260.48, 270.46, 280.44, 290.42, 300.4 , 310.38,
#         320.36, 330.34, 340.32, 350.3 , 360.28, 370.26, 380.24, 390.22,
#         400.2 , 410.18, 420.16, 430.14, 440.12, 450.1 , 460.08, 470.06,
#         480.04, 490.02, 500.  , 509.98, 519.96, 529.94, 539.92, 549.9 ,
#         559.88, 569.86, 579.84, 589.82, 599.8 , 609.78, 619.76, 629.74,
#         639.72, 649.7 , 659.68, 669.66, 679.64, 689.62, 699.6 , 709.58,
#         719.56, 729.54, 739.52, 749.5 , 759.48, 769.46, 779.44, 789.42,
#         799.4 , 809.38, 819.36, 829.34, 839.32, 849.3 , 859.28, 869.26,
#         879.24, 889.22, 899.2 , 909.18, 919.16, 929.14, 939.12, 949.1 ,
#         959.08, 969.06, 979.04, 989.02, 999.  ]),
#  <BarContainer object of 100 artists>)

# %%
# We see spikes in listings at $1, $100, $250, $500, and $800. 
# Since we are looking at vehicle listings, it is reasonable to limit the lower end at $250

clean_listings_df = clean_listings_df[clean_listings_df['price']>250]
clean_listings_df.shape

# We have now cut down the list to 231,226 listings(-0.9%) ranging in price from $250 to $100,000.
# Out:
# (231266, 9)

# %% [markdown]
# <b> Now that we have filtered the dataset on price (231,266 listings between $250 - $100,000), we can look at other metrics.
#
# Let's look at mileage. </b>

# %%
# Let's visualize odometer readings

fig = plt.figure(figsize=(5,5))
plt.title("Craigslist Vehicle Mileage")
plt.ylabel("Miles")
plt.boxplot('odometer', data=clean_listings_df,showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbdba502520>,
#   <matplotlib.lines.Line2D at 0x7fbdba502880>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbdba502be0>,
#   <matplotlib.lines.Line2D at 0x7fbdba502f40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbdba5021c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbe2ed7f2e0>],
#  'fliers': [],
#  'means': []}

# %%
# Let's look at descriptive statistics

clean_listings_df['odometer'].describe()
# Out:
# count    2.312660e+05
# mean     1.007950e+05
# std      1.133834e+05
# min      0.000000e+00
# 25%      4.662050e+04
# 50%      9.404050e+04
# 75%      1.399780e+05
# max      1.000000e+07
# Name: odometer, dtype: float64

# %%
# Let's view this in a histogram

fig = plt.figure(figsize=(5,5))
plt.hist(cheap_df['odometer'],100)

# We see that almost all the listings are under 500,000 miles.
# Out:
# (array([9.400e+02, 1.303e+03, 7.400e+02, 6.950e+02, 5.190e+02, 3.770e+02,
#         3.640e+02, 2.660e+02, 1.990e+02, 1.290e+02, 7.700e+01, 3.300e+01,
#         2.300e+01, 9.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([      0.,   25000.,   50000.,   75000.,  100000.,  125000.,
#          150000.,  175000.,  200000.,  225000.,  250000.,  275000.,
#          300000.,  325000.,  350000.,  375000.,  400000.,  425000.,
#          450000.,  475000.,  500000.,  525000.,  550000.,  575000.,
#          600000.,  625000.,  650000.,  675000.,  700000.,  725000.,
#          750000.,  775000.,  800000.,  825000.,  850000.,  875000.,
#          900000.,  925000.,  950000.,  975000., 1000000., 1025000.,
#         1050000., 1075000., 1100000., 1125000., 1150000., 1175000.,
#         1200000., 1225000., 1250000., 1275000., 1300000., 1325000.,
#         1350000., 1375000., 1400000., 1425000., 1450000., 1475000.,
#         1500000., 1525000., 1550000., 1575000., 1600000., 1625000.,
#         1650000., 1675000., 1700000., 1725000., 1750000., 1775000.,
#         1800000., 1825000., 1850000., 1875000., 1900000., 1925000.,
#         1950000., 1975000., 2000000., 2025000., 2050000., 2075000.,
#         2100000., 2125000., 2150000., 2175000., 2200000., 2225000.,
#         2250000., 2275000., 2300000., 2325000., 2350000., 2375000.,
#         2400000., 2425000., 2450000., 2475000., 2500000.]),
#  <BarContainer object of 100 artists>)

# %%
# The low end of this data set appears reasonable. The box and whiskers plot shows values beyond 250,000 or so miles to be outliers. 
# Let's see how many data points fall in this category.

clean_listings_df[clean_listings_df['odometer']>250000] 

# There are 3,633 listings with over 250,000 miles.
# Out:
#                 id  price    year manufacturer                  model    fuel  \
# 4       7184712241  16995  2007.0          gmc  sierra classic 2500hd  diesel
# 9       7184708752  12995  2004.0          ram                   2500  diesel
# 22      7184570302   7500  2009.0         ford                  f-150     gas
# 28      7195084414   9900  2003.0    chevrolet              silverado  diesel
# 58      7183953590   4725  2012.0       toyota               camry le     gas
# ...            ...    ...     ...          ...                    ...     ...
# 423483  7183988157   4995  2004.0         ford              excursion     gas
# 423641  7195187671   3700  1995.0         ford                   f250  diesel
# 423673  7183364862  11990  2008.0         ford       super duty f-250  diesel
# 423795  7186061752   1200  2004.0       saturn                    vue     gas
# 423845  7195062876   1600  2004.0        volvo                   xc70     gas
#
#         odometer title_status transmission
# 4       254217.0        clean    automatic
# 9       309621.0        clean    automatic
# 22      271000.0        clean    automatic
# 28      299000.0        clean    automatic
# 58      262000.0        clean    automatic
# ...          ...          ...          ...
# 423483  287000.0        clean    automatic
# 423641  270000.0        clean       manual
# 423673  274000.0        clean    automatic
# 423795  322000.0        clean       manual
# 423845  292255.0        clean    automatic
#
# [3633 rows x 9 columns]

# %%
# Let's remove outliers over 250,000 miles
clean_listings_df = clean_listings_df[clean_listings_df['odometer']<250000]
clean_listings_df.describe()

# We now have a dataset of 227,475 listings (-1.6%)
# Out:
#                  id          price           year       odometer
# count  2.274750e+05  227475.000000  227475.000000  227475.000000
# mean   7.189038e+09   15910.989827    2011.115964   95465.989150
# std    4.759653e+06   12422.730282       7.636114   57781.157951
# min    7.178302e+09     251.000000    1911.000000       0.000000
# 25%    7.185433e+09    6990.000000    2008.000000   45798.000000
# 50%    7.190007e+09   12950.000000    2013.000000   92856.000000
# 75%    7.193339e+09   20994.000000    2016.000000  137000.000000
# max    7.195225e+09   99999.000000    2021.000000  249999.000000

# %%
# Let's take a look at a histogram of the remaining listings.

fig = plt.figure(figsize=(5,5))
plt.hist(clean_listings_df['odometer'],50)

# This looks good. We can move on to the next metric.
# Out:
# (array([6264., 3669., 5268., 5814., 6460., 7025., 7396., 7288., 6596.,
#         5932., 5467., 5308., 5892., 5784., 6267., 6323., 6472., 6308.,
#         7330., 7297., 6707., 6177., 6251., 6302., 6239., 6023., 6235.,
#         5367., 5565., 4684., 4707., 4392., 4062., 3774., 3674., 3130.,
#         2986., 2504., 2159., 1965., 2159., 1543., 1244., 1023., 1068.,
#          865.,  822.,  600.,  604.,  484.]),
#  array([     0.  ,   4999.98,   9999.96,  14999.94,  19999.92,  24999.9 ,
#          29999.88,  34999.86,  39999.84,  44999.82,  49999.8 ,  54999.78,
#          59999.76,  64999.74,  69999.72,  74999.7 ,  79999.68,  84999.66,
#          89999.64,  94999.62,  99999.6 , 104999.58, 109999.56, 114999.54,
#         119999.52, 124999.5 , 129999.48, 134999.46, 139999.44, 144999.42,
#         149999.4 , 154999.38, 159999.36, 164999.34, 169999.32, 174999.3 ,
#         179999.28, 184999.26, 189999.24, 194999.22, 199999.2 , 204999.18,
#         209999.16, 214999.14, 219999.12, 224999.1 , 229999.08, 234999.06,
#         239999.04, 244999.02, 249999.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# <b> Now that we have filtered the dataset on price and mileage (227,475 listings between $250 - $100,000 with under 250,000 miles), let's look at the range of years.
#
# Based on the descriptive statics from before, we can expect the values to be skewed towards newer cars. Let's try and filter our dataset </b>

# %%
# Let's look at the remaining unique values for the categorical columns again.

# Categorical Columns
print('Categorical Columns: \n\n')
print(f'Unique Years: ',clean_listings_df.year.unique(),'\n')
print(f'Unique Manufacturers: ',clean_listings_df.manufacturer.unique(),'\n')
print(f'Unique Models: ',clean_listings_df.model.unique(),'\n')
print(f'Unique Fuel Types: ',clean_listings_df.fuel.unique(),'\n')
print(f'Unique Title Statuses: ',clean_listings_df.title_status.unique(),'\n')
print(f'Unique Transmission Types: ',clean_listings_df.transmission.unique(),'\n\n')

# Numberical Columns
print('Numerical Columns: \n\n')
clean_listings_df.describe()
# Out:
# Categorical Columns:
#
#
# Unique Years:  [2000. 2013. 2012. 2010. 2011. 2014. 2009. 2008. 1994. 1997. 2007. 2019.
#  2015. 2016. 2006. 2017. 2005. 1964. 1998. 2001. 2002. 2004. 2018. 1989.
#  2003. 1990. 1967. 1992. 1993. 1999. 1986. 1995. 1996. 2020. 1963. 1966.
#  1983. 1972. 1952. 1987. 1981. 1991. 1979. 1960. 1927. 1973. 1977. 1969.
#  1982. 1953. 1978. 1988. 1957. 1968. 1984. 1934. 1980. 1985. 1970. 1974.
#  1971. 1962. 2021. 1965. 1919. 1939. 1948. 1940. 1975. 1950. 1976. 1959.
#  1930. 1932. 1955. 1956. 1951. 1949. 1929. 1954. 1923. 1931. 1933. 1936.
#  1941. 1921. 1947. 1958. 1946. 1961. 1937. 1935. 1926. 1928. 1924. 1938.
#  1911. 1942.]
#
# Unique Manufacturers:  ['gmc' 'hyundai' 'toyota' 'ford' 'chevrolet' 'buick' 'jeep' 'subaru'
#  'nissan' 'dodge' 'audi' 'rover' 'lexus' 'honda' 'ram' 'mini'
#  'mercedes-benz' 'cadillac' 'bmw' 'kia' 'volvo' 'jaguar' 'chrysler'
#  'acura' 'mitsubishi' 'mazda' 'volkswagen' 'pontiac' 'lincoln' 'infiniti'
#  'saturn' 'mercury' 'fiat' 'tesla' 'ferrari' 'land rover'
#  'harley-davidson' 'datsun' 'alfa-romeo' 'morgan' 'aston-martin' 'porche']
#
# Unique Models:  ['new sierra 1500' 'sonata' 'prius' ... '280 sl' 'sienns xlt awd'
#  'ranchero gt cobra']
#
# Unique Fuel Types:  ['gas' 'hybrid' 'diesel' 'electric' 'other']
#
# Unique Title Statuses:  ['clean' 'lien' 'rebuilt' 'salvage' 'parts only' 'missing']
#
# Unique Transmission Types:  ['automatic' 'manual' 'other']
#
#
# Numerical Columns:
#                  id          price           year       odometer
# count  2.274750e+05  227475.000000  227475.000000  227475.000000
# mean   7.189038e+09   15910.989827    2011.115964   95465.989150
# std    4.759653e+06   12422.730282       7.636114   57781.157951
# min    7.178302e+09     251.000000    1911.000000       0.000000
# 25%    7.185433e+09    6990.000000    2008.000000   45798.000000
# 50%    7.190007e+09   12950.000000    2013.000000   92856.000000
# 75%    7.193339e+09   20994.000000    2016.000000  137000.000000
# max    7.195225e+09   99999.000000    2021.000000  249999.000000

# %%
# Let's look at a histogram of the model years

fig = plt.figure(figsize=(5,5))
plt.hist(clean_listings_df['year'],50)
# Out:
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 2.0000e+00,
#         8.0000e+00, 1.0000e+00, 2.1000e+01, 2.5000e+01, 2.2000e+01,
#         1.4000e+01, 2.0000e+01, 1.5000e+01, 5.0000e+01, 1.0000e+00,
#         1.0000e+01, 3.0000e+01, 3.7000e+01, 1.6000e+01, 2.9000e+01,
#         1.1600e+02, 2.7000e+01, 4.0000e+01, 1.4300e+02, 1.7700e+02,
#         3.2000e+02, 2.5200e+02, 2.0500e+02, 1.7800e+02, 1.6300e+02,
#         4.3700e+02, 1.7800e+02, 1.8700e+02, 3.5600e+02, 4.3700e+02,
#         7.6400e+02, 5.4000e+02, 8.9500e+02, 1.2440e+03, 1.9860e+03,
#         6.2150e+03, 7.8240e+03, 1.2455e+04, 1.8412e+04, 1.9284e+04,
#         3.7685e+04, 3.1286e+04, 3.1368e+04, 3.7165e+04, 1.6833e+04]),
#  array([1911. , 1913.2, 1915.4, 1917.6, 1919.8, 1922. , 1924.2, 1926.4,
#         1928.6, 1930.8, 1933. , 1935.2, 1937.4, 1939.6, 1941.8, 1944. ,
#         1946.2, 1948.4, 1950.6, 1952.8, 1955. , 1957.2, 1959.4, 1961.6,
#         1963.8, 1966. , 1968.2, 1970.4, 1972.6, 1974.8, 1977. , 1979.2,
#         1981.4, 1983.6, 1985.8, 1988. , 1990.2, 1992.4, 1994.6, 1996.8,
#         1999. , 2001.2, 2003.4, 2005.6, 2007.8, 2010. , 2012.2, 2014.4,
#         2016.6, 2018.8, 2021. ]),
#  <BarContainer object of 50 artists>)

# %%
clean_listings_df[clean_listings_df['year']<1985]
# Out:
#                 id  price    year   manufacturer              model    fuel  \
# 50      7184080602  27000  1964.0          dodge             polara     gas
# 118     7187986347  26500  1967.0      chevrolet               c-10     gas
# 330     7180617522   7200  1963.0      chevrolet      corvair monza     gas
# 496     7185637009   2500  1966.0           ford               f100     gas
# 663     7185170223   7000  1963.0        pontiac            tempest     gas
# ...            ...    ...     ...            ...                ...     ...
# 423769  7186741190   4500  1977.0          buick            lesabre     gas
# 423776  7193488655  60000  1970.0  mercedes-benz             280 sl     gas
# 423802  7195143461   6500  1983.0         toyota     pick up diesel  diesel
# 423811  7185734413  28000  1957.0      chevrolet          210 coupe     gas
# 423840  7185260804  30000  1970.0           ford  ranchero gt cobra     gas
#
#         odometer title_status transmission
# 50       36000.0        clean    automatic
# 118        500.0        clean    automatic
# 330     105311.0        clean       manual
# 496     100755.0        clean       manual
# 663      96000.0        clean       manual
# ...          ...          ...          ...
# 423769   96660.0        clean    automatic
# 423776   71000.0        clean    automatic
# 423802  165103.0        clean       manual
# 423811   96731.0        clean       manual
# 423840   53325.0        clean    automatic
#
# [2895 rows x 9 columns]

# %%
clean_listings_df.boxplot('price', 'fuel', showfliers=False)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='fuel'>

# %%
clean_listings_df.boxplot('price', 'manufacturer', widths=.6, showfliers=False)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='manufacturer'>

# %%
fuel_percents = 100 * clean_listings_df.groupby(["fuel"]).sum()["year"] /clean_listings_df["year"].sum()


# Build percentage of rides by city type pie chart.
plt.subplots(figsize=(10, 6))
plt.pie(fuel_percents,
    labels=["Diesel", "Electric", "Gas", "Hybrid", "Other"],
    explode=[0, 0, 0.1,0,0],
    autopct='%1.1f%%',
    shadow=True, startangle=165)
plt.title("Fuel Types In Craigslist Vehicle Listings")


# Show Figure
plt.show()

# %%
transmission_percents = 100 * clean_listings_df.groupby(["transmission"]).sum()["year"] /clean_listings_df["year"].sum()


# Build percentage of rides by city type pie chart.
plt.subplots(figsize=(10, 6))
plt.pie(transmission_percents,
    labels=["Automatic", "Manual", "Unknown"],
    explode=[0.1, 0, 0],
    autopct='%1.1f%%',
    shadow=True, startangle=165)
plt.title("Transmission Types In Craigslist Vehicle Listings")


# Show Figure
plt.show()

# %%
# Let's plot mileage and price on a scatter plot to see if there is any correlation

fig = plt.figure(figsize=(20,20))
y = clean_listings_df['price']
x = clean_listings_df['odometer']
plt.scatter(x, y)
plt.title('Price vs. Mileage')
plt.xlabel('Mileage')
plt.ylabel('Price ($)')
plt.show()

# %% [markdown]
# #### Let's visualize the mileage and price by manufacturer for our remaining data

# %%
import seaborn as sns

# %%
clean_listings_df=clean_listings_df.sort_values(by=['odometer'],ascending=False)
plt.figure(figsize=(25,15))
sns.boxplot(x=clean_listings_df.manufacturer, y=clean_listings_df.odometer)
plt.xticks(rotation= 90)
plt.xlabel('Manufacturer')
plt.ylabel('Odometer')
plt.show()

# %%
clean_listings_df=clean_listings_df.sort_values(by=['price'],ascending=False)
plt.figure(figsize=(25,15))
sns.boxplot(x=clean_listings_df.manufacturer, y=clean_listings_df.price)
plt.xticks(rotation= 90)
plt.xlabel('Manufacturer')
plt.ylabel('Price')
plt.show()

# %%
clean_listings_df=clean_listings_df.sort_values(by=['price'],ascending=False)
plt.figure(figsize=(25,15))
sns.boxplot(x=clean_listings_df.transmission, y=clean_listings_df.price)
plt.xticks(rotation= 90)
plt.xlabel('Transmission')
plt.ylabel('Price')
plt.show()

# %%
clean_listings_df=clean_listings_df.sort_values(by=['price'],ascending=False)
plt.figure(figsize=(25,15))
sns.boxplot(x=clean_listings_df.fuel, y=clean_listings_df.price)
plt.xticks(rotation= 90)
plt.xlabel('Fuel')
plt.ylabel('Price')
plt.show()

# %%
clean_listings_df=clean_listings_df.sort_values(by=['price'],ascending=False)
plt.figure(figsize=(25,15))
sns.boxplot(x=clean_listings_df.title_status, y=clean_listings_df.price)
plt.xticks(rotation= 90)
plt.xlabel('Title')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.countplot(x='manufacturer', data=clean_listings_df, order = clean_listings_df['manufacturer'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='manufacturer', ylabel='count'>

# %% [markdown]
# ### Load the Data

# %%
# Import Dependencies to create a database engine and define the database string:
from pathlib import Path

Path('../Resources/craigslist_cars.db').touch()

# %%
import sqlite3

conn = sqlite3.connect('../Resources/craigslist_cars.db')
c = conn.cursor()

# %%
# Create the listings table
c.execute('''CREATE TABLE listings(id, price, year, manufacturer, model, fuel, odometer, title_status, transmission)''')

# %%
clean_listings_df.to_sql('listings', conn, if_exists='append', index=False)

# %%
# Create the location table
c.execute('''CREATE TABLE location(id, region, county, state, lat, long)''')

location_df.to_sql('location', conn, if_exists='append', index=False)

# %%
# Create the description table
c.execute('''CREATE TABLE description(id, description)''')

desc_df.to_sql('description', conn, if_exists='append', index=False)

# %% [markdown]
# ### Now the data has been loaded into an SQLite database in the Resources folder.
#
# It is set up in the following way:
#
#     - The `listings` table contains our cleaned listings with 227,475 rows
#     - The `location` and `description` tables include data for the original 423,857 rows
#
#
# There is now a 1GB database file that I will pull from in the data visualization portion of this project.
